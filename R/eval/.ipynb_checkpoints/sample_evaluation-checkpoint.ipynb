# %%
import os
import json
from glob import glob

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dpg_name = "dgp4"
root_dir = f"/Users/s11616/Desktop/{dpg_name}"

# %%
rows = []
for exp_name in os.listdir(root_dir):
    jsonfile_paths = glob(os.path.join(root_dir, exp_name, '*.json'))
    
    for jsonfile_path in jsonfile_paths:
        
        jsonfile_name = jsonfile_path.split('/')[-1]
        if jsonfile_name == 'RobynModel-inputs.json':
            continue
        
        with open(jsonfile_path) as f:
            dic = json.load(f)
        
        for i, vals in enumerate(dic['ExportedModel']['summary']):
            if vals['variable'] == '(Intercept)':
                continue
    
            rows.append([exp_name, jsonfile_name, vals['variable'].split('_')[-1], vals['performance']])

# %%
df = pd.DataFrame(rows)
df.columns = ['EXP_NAME', 'FILENAME', 'MEDIA', 'PRED_ROI']

df['DPG'] = dpg_name

# %%
df_true = pd.read_csv(os.path.join(root_dir, os.listdir(root_dir)[0], 'true_roi.csv'))

# %%
df_true
# Out:
#                                       x
# 0  roi of Facebook is: 1.91756896992852
# 1       roi of TV is: 0.477520179937832

# %%
# Glue Code
_df_true = pd.DataFrame({'MEDIA': ['Facebook', 'TV'], 'TRUE_ROI': [1.91756896992852, 0.475175414894113]})

# %%
df = pd.merge(df, _df_true, on='MEDIA')

# %%
df
# Out:
#                               EXP_NAME                 FILENAME     MEDIA  \
# 0                 prophet_FALSE_calib_   RobynModel-2_48_1.json  Facebook
# 1                 prophet_FALSE_calib_   RobynModel-2_34_3.json  Facebook
# 2                 prophet_FALSE_calib_   RobynModel-2_49_2.json  Facebook
# 3                 prophet_FALSE_calib_  RobynModel-1_61_15.json  Facebook
# 4                 prophet_FALSE_calib_   RobynModel-1_66_7.json  Facebook
# 5                 prophet_FALSE_calib_   RobynModel-1_57_4.json  Facebook
# 6   prophet_FALSE_calib_spend_Facebook   RobynModel-1_33_9.json  Facebook
# 7   prophet_FALSE_calib_spend_Facebook   RobynModel-1_31_9.json  Facebook
# 8   prophet_FALSE_calib_spend_Facebook   RobynModel-1_27_9.json  Facebook
# 9   prophet_FALSE_calib_spend_Facebook   RobynModel-1_31_2.json  Facebook
# 10  prophet_FALSE_calib_spend_Facebook   RobynModel-1_46_4.json  Facebook
# 11  prophet_FALSE_calib_spend_Facebook  RobynModel-1_36_13.json  Facebook
# 12        prophet_FALSE_calib_spend_TV   RobynModel-1_35_2.json  Facebook
# 13        prophet_FALSE_calib_spend_TV   RobynModel-1_39_2.json  Facebook
# 14        prophet_FALSE_calib_spend_TV   RobynModel-1_29_8.json  Facebook
# 15        prophet_FALSE_calib_spend_TV  RobynModel-3_35_10.json  Facebook
# 16        prophet_FALSE_calib_spend_TV  RobynModel-1_33_12.json  Facebook
# 17        prophet_FALSE_calib_spend_TV  RobynModel-3_48_10.json  Facebook
# 18        prophet_FALSE_calib_spend_TV   RobynModel-1_45_8.json  Facebook
# 19                prophet_FALSE_calib_   RobynModel-2_48_1.json        TV
# 20                prophet_FALSE_calib_   RobynModel-2_34_3.json        TV
# 21                prophet_FALSE_calib_   RobynModel-2_49_2.json        TV
# 22                prophet_FALSE_calib_  RobynModel-1_61_15.json        TV
# 23                prophet_FALSE_calib_   RobynModel-1_66_7.json        TV
# 24                prophet_FALSE_calib_   RobynModel-1_57_4.json        TV
# 25  prophet_FALSE_calib_spend_Facebook   RobynModel-1_33_9.json        TV
# 26  prophet_FALSE_calib_spend_Facebook   RobynModel-1_31_9.json        TV
# 27  prophet_FALSE_calib_spend_Facebook   RobynModel-1_27_9.json        TV
# 28  prophet_FALSE_calib_spend_Facebook   RobynModel-1_31_2.json        TV
# 29  prophet_FALSE_calib_spend_Facebook   RobynModel-1_46_4.json        TV
# 30  prophet_FALSE_calib_spend_Facebook  RobynModel-1_36_13.json        TV
# 31        prophet_FALSE_calib_spend_TV   RobynModel-1_35_2.json        TV
# 32        prophet_FALSE_calib_spend_TV   RobynModel-1_39_2.json        TV
# 33        prophet_FALSE_calib_spend_TV   RobynModel-1_29_8.json        TV
# 34        prophet_FALSE_calib_spend_TV  RobynModel-3_35_10.json        TV
# 35        prophet_FALSE_calib_spend_TV  RobynModel-1_33_12.json        TV
# 36        prophet_FALSE_calib_spend_TV  RobynModel-3_48_10.json        TV
# 37        prophet_FALSE_calib_spend_TV   RobynModel-1_45_8.json        TV
#
#     PRED_ROI   DPG  TRUE_ROI
# 0     6.1715  dgp4  1.917569
# 1     5.9988  dgp4  1.917569
# 2     3.9586  dgp4  1.917569
# 3     5.6538  dgp4  1.917569
# 4     4.9228  dgp4  1.917569
# 5     4.7655  dgp4  1.917569
# 6     3.0253  dgp4  1.917569
# 7     3.1076  dgp4  1.917569
# 8     3.2841  dgp4  1.917569
# 9     2.8175  dgp4  1.917569
# 10    3.0818  dgp4  1.917569
# 11    3.1368  dgp4  1.917569
# 12    4.5121  dgp4  1.917569
# 13    4.5120  dgp4  1.917569
# 14    5.0316  dgp4  1.917569
# 15    8.6489  dgp4  1.917569
# 16    5.8962  dgp4  1.917569
# 17    8.0161  dgp4  1.917569
# 18    5.0512  dgp4  1.917569
# 19    3.9529  dgp4  0.475175
# 20    1.9188  dgp4  0.475175
# 21    3.9455  dgp4  0.475175
# 22    4.4883  dgp4  0.475175
# 23    4.7005  dgp4  0.475175
# 24    4.0723  dgp4  0.475175
# 25    0.3485  dgp4  0.475175
# 26    0.2773  dgp4  0.475175
# 27    0.0000  dgp4  0.475175
# 28    0.6681  dgp4  0.475175
# 29    0.8710  dgp4  0.475175
# 30    0.4540  dgp4  0.475175
# 31    1.5202  dgp4  0.475175
# 32    1.6977  dgp4  0.475175
# 33    1.5935  dgp4  0.475175
# 34    1.7875  dgp4  0.475175
# 35    1.7098  dgp4  0.475175
# 36    1.3946  dgp4  0.475175
# 37    1.7826  dgp4  0.475175

# %%
def ape(pred, true):
    return abs((pred - true) / true)

# %%
df['APE_ROI'] = ape(df['PRED_ROI'], df['TRUE_ROI'])

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x = "EXP_NAME", y = "APE_ROI", data = df, hue='MEDIA')
plt.grid()
